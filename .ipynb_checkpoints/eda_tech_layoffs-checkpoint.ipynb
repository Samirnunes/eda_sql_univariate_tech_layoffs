# %% [markdown]
# # Análise Univariada em SQL: Layoffs nas Empresas de Tecnologia (2022-2023)

# %% [markdown]
# Fonte dos dados: Kaggle
#
# Link: https://www.kaggle.com/datasets/salimwid/technology-company-layoffs-20222023-data

# %% [markdown]
# ## Importando bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sqlite3

# %% [markdown]
# ## Adicionando ID's para as linhas e corrigindo o formato das datas para SQL (YYYY-MM-DD)

# %%
original_df = pd.read_csv('data/tech_layoffs_original.csv')

# %%
original_df['ID'] = original_df.index
def correct_date_format(date):
    splited_date = date.split('/')
    year = splited_date[2]
    month = splited_date[0]
    day = splited_date[1]
    if float(day) < 10:
        day = '0' + day
    if float(month) < 10:
        month = '0' + month
    return year + '-' + month + '-' + day

original_df['reported_date'] = original_df['reported_date'].apply(correct_date_format)

# %% [markdown]
# Ajeitando a ordem das colunas:

# %%
cols = original_df.columns.to_list()

# %%
cols = cols[-1:] + cols[:-1]

# %%
new_df = original_df[cols]

# %% [markdown]
# Passando para .csv:

# %%
new_df.to_csv('data/tech_layoffs_new.csv', index = False)

# %% [markdown]
# A partir desse arquivo, conseguimos criar um banco de dados SQLite para iniciarmos a conexão. As seguintes queries foram usadas para corrigir o banco de dados no SQLiteStudio:

# %% [markdown]
# ``` sqlite
# PRAGMA foreign_keys = 0;
#
# CREATE TABLE sqlitestudio_temp_table AS SELECT *
#                                           FROM data;
#
# DROP TABLE data;
#
# CREATE TABLE data (
#     ID                            INTEGER PRIMARY KEY,
#     company                       TEXT,
#     total_layoffs                 INTEGER,
#     impacted_workforce_percentage NUMERIC,
#     reported_date                 TEXT,
#     industry                      TEXT,
#     headquarter_location          TEXT,
#     sources                       TEXT,
#     status                        TEXT,
#     additional_notes              TEXT
# );
#
# INSERT INTO data (
#                      ID,
#                      company,
#                      total_layoffs,
#                      impacted_workforce_percentage,
#                      reported_date,
#                      industry,
#                      headquarter_location,
#                      sources,
#                      status,
#                      additional_notes
#                  )
#                  SELECT ID,
#                         company,
#                         total_layoffs,
#                         impacted_workforce_percentage,
#                         reported_date,
#                         industry,
#                         headquarter_location,
#                         sources,
#                         status,
#                         additional_notes
#                    FROM sqlitestudio_temp_table;
#
# DROP TABLE sqlitestudio_temp_table;
#
# PRAGMA foreign_keys = 1;
#
# UPDATE data
# SET total_layoffs = NULL
# WHERE total_layoffs = "Unclear";
#
# UPDATE data
# SET impacted_workforce_percentage = NULL
# WHERE impacted_workforce_percentage = "Unclear";
# ```

# %% [markdown]
# ## Conectando com o banco de dados SQLite

# %%
database = 'data/tech_layoffs.db'
conn = sqlite3.connect(database)

# %% [markdown]
# ---

# %% [markdown]
# # Data Profiling: visão e estatísticas gerais

# %% [markdown]
# ### Quantidade de linhas e colunas

# %%
cols_info = pd.read_sql('''PRAGMA TABLE_INFO(data)''', conn)

nrows = pd.read_sql('''SELECT COUNT(*) FROM data''', conn).values[0][0]
ncols = len(cols_info)
print(f'(linhas, colunas): ({nrows}, {ncols})')
# Out:
# (linhas, colunas): (489, 10)

# %% [markdown]
# ### Descrição das colunas

# %%
cols_info
# Out:
#    cid                           name     type  notnull dflt_value  pk
# 0    0                             ID  INTEGER        0       None   1
# 1    1                        company     TEXT        0       None   0
# 2    2                  total_layoffs  INTEGER        0       None   0
# 3    3  impacted_workforce_percentage  NUMERIC        0       None   0
# 4    4                  reported_date     TEXT        0       None   0
# 5    5                       industry     TEXT        0       None   0
# 6    6           headquarter_location     TEXT        0       None   0
# 7    7                        sources     TEXT        0       None   0
# 8    8                         status     TEXT        0       None   0
# 9    9               additional_notes     TEXT        0       None   0

# %% [markdown]
# - __ID__: chave primária inteira;
#
# - __company__: empresa que realizou o layoff (demissão em massa);
#
# - __total_layoffs__: número de funcionários demitidos até janeiro de 2023;
#
# - __impacted_workforce_percentage__: porcentagem da força de trabalho total da empresa que foi demitida pelos layoffs;
#
# - __reported_date__: data em que o primeiro layoff ou planos de layoff da empresa foram anunciados;
#
# - __industry__: segmentos de atuação da empresa;
#
# - __headquarter_location__: localização da sede da empresa;
#
# - __sources__: fonte dos dados;
#
# - __status__: se a empresa é pública ou privada.
#
# - __additional_notes__: notas adicionais sobre o plano de layoffs da empresa.

# %% [markdown]
# ### Valores iniciais e finais do dataframe

# %%
pd.read_sql('''SELECT * FROM data 
               LIMIT 5''', conn)
# Out:
#    ID         company  total_layoffs  impacted_workforce_percentage  \
# 0   0            C2FO           20.0                              2
# 1   1        VideoAmp            NaN                              2
# 2   2        Amperity           13.0                              3
# 3   3         Addepar           20.0                              3
# 4   4  Thirty Madison           24.0                              3
#
#   reported_date                 industry headquarter_location  \
# 0    2022-12-09        Fintech, payments          Leawood, KS
# 1    2022-09-19    Advertising platforms          Los Angeles
# 2    2022-08-20          Saas, analytics              Seattle
# 3    2023-01-18  fintech, data analytics    Mountain View, CA
# 4    2022-05-13              Health Care             New York
#
#                         sources   status  \
# 0  Kansas City Business Journal  Private
# 1                  Company memo  Private
# 2                      Geekwire  Private
# 3                       Fortune  Private
# 4                         Axios  Private
#
#                                     additional_notes
# 0
# 1
# 2
# 3
# 4  Per Axios, 22 of the employees laid off were f...

# %%
pd.read_sql('''SELECT * FROM data 
               ORDER BY ID DESC
               LIMIT 5''', conn)
# Out:
#     ID     company  total_layoffs impacted_workforce_percentage reported_date  \
# 0  488   Blueboard            NaN                          None    2022-11-03
# 1  487      Skillz            NaN                          None    2022-08-29
# 2  486  LivePerson            NaN                          None    2022-09-15
# 3  485      Oracle            NaN                          None    2022-08-01
# 4  484  Salesforce         9090.0                          None    2023-01-04
#
#                      industry headquarter_location           sources   status  \
# 0         Enterprise Software        San Francisco  LinkedIn reports  Private
# 1         Mobile Apps, Gaming        San Francisco     Seeking Alpha   Public
# 2            Customer service             New York          LinkedIn   Public
# 3   SaaS, enterprise software               Austin   The Information   Public
# 4  enterprise tech, analytics        San Francisco    New York Times   Public
#
#                                     additional_notes
# 0
# 1
# 2
# 3  The Information reported thousands of people w...
# 4

# %% [markdown]
# ## Análise univariada: estudando cada coluna separadamente

# %% [markdown]
# ### total_layoffs

# %% [markdown]
# #### Representações analíticas

# %% [markdown]
# Quantidade de demissões realizadas e número de empresas que realizaram tais números:

# %%
pd.read_sql('''SELECT DISTINCT total_layoffs, COUNT(*) AS companies
               FROM data
               GROUP BY total_layoffs
               ORDER BY total_layoffs''', conn)
# Out:
#      total_layoffs  companies
# 0              NaN        182
# 1              5.0          1
# 2              7.0          1
# 3             10.0          1
# 4             11.0          1
# ..             ...        ...
# 145         9090.0          1
# 146        10000.0          1
# 147        11000.0          1
# 148        12000.0          1
# 149        18000.0          1
#
# [150 rows x 2 columns]

# %% [markdown]
# Média de demissões:

# %%
pd.read_sql('''SELECT ROUND(AVG(total_layoffs), 0) AS mean_total_layoffs
               FROM data''', conn)
# Out:
#    mean_total_layoffs
# 0               450.0

# %% [markdown]
# Valores máximos e mínimos, e em quais empresas eles ocorreram:

# %%
pd.read_sql('''SELECT company, total_layoffs FROM data
               WHERE total_layoffs = (SELECT MAX(total_layoffs) FROM data)
               OR total_layoffs = (SELECT MIN(total_layoffs) FROM data)
               ORDER BY total_layoffs ASC''', conn)
# Out:
#   company  total_layoffs
# 0   Woven              5
# 1  Amazon          18000

# %% [markdown]
# #### Representações gráficas

# %% [markdown]
# Representando a distribuição do número de demissões feitos por empresas através de um boxplot:
#
# Obs: cada ponto representa uma empresa.

# %%
plot_data = pd.read_sql('''SELECT total_layoffs FROM data
                           WHERE total_layoffs IS NOT NULL''', conn)
plt.boxplot(plot_data)
plt.suptitle('Boxplot da distribuição do número de demissões', fontsize = '16')
plt.title('Cada ponto representa uma empresa com determinado número de funcionários demitidos. O maior número de demissões foi de 18000 e, o menor, de 5.')
plt.ylabel('Número de demissões')
# Out:
# Text(0, 0.5, 'Número de demissões')

# %% [markdown]
# ### impacted_workforce_percentage

# %% [markdown]
# #### Representações analíticas

# %% [markdown]
# Valores na coluna e suas contagens:

# %%
pd.read_sql('''SELECT impacted_workforce_percentage, COUNT(*) AS count
               FROM data
               GROUP BY impacted_workforce_percentage
               ORDER BY impacted_workforce_percentage''', conn)
# Out:
#     impacted_workforce_percentage  count
# 0                             NaN    133
# 1                             1.0      2
# 2                             2.0      3
# 3                             3.0      8
# 4                             4.0      4
# 5                             5.0     20
# 6                             6.0     12
# 7                             7.0     15
# 8                             8.0     12
# 9                             9.0      9
# 10                           10.0     32
# 11                           11.0     10
# 12                           12.0     10
# 13                           13.0     11
# 14                           14.0      9
# 15                           15.0     27
# 16                           16.0      3
# 17                           17.0      8
# 18                           18.0      7
# 19                           19.0      7
# 20                           20.0     29
# 21                           21.0      5
# 22                           22.0      2
# 23                           23.0      4
# 24                           24.0      3
# 25                           25.0     17
# 26                           26.0      1
# 27                           27.0      3
# 28                           28.0      1
# 29                           29.0      1
# 30                           30.0     10
# 31                           32.0      2
# 32                           33.0     13
# 33                           34.0      1
# 34                           35.0      4
# 35                           37.0      2
# 36                           39.0      1
# 37                           40.0      4
# 38                           42.0      1
# 39                           43.0      1
# 40                           46.0      2
# 41                           48.0      1
# 42                           50.0      6
# 43                           54.0      1
# 44                           60.0      1
# 45                           70.0      1
# 46                           74.0      1
# 47                           75.0      2
# 48                           76.0      1
# 49                          100.0     26

# %% [markdown]
# Valores máximo e mínimo, e em quais empresas eles ocorreram:

# %%
pd.read_sql('''SELECT company, impacted_workforce_percentage FROM data
               WHERE impacted_workforce_percentage = (SELECT MAX(impacted_workforce_percentage) FROM data)
               OR impacted_workforce_percentage = (SELECT MIN(impacted_workforce_percentage) FROM data)
               ORDER BY impacted_workforce_percentage ASC''', conn)
# Out:
#                company  impacted_workforce_percentage
# 0                   F5                              1
# 1               Affirm                              1
# 2   Butler Hospitality                            100
# 3            SummerBio                            100
# 4                Reali                            100
# 5                 Fast                            100
# 6       Protocol Media                            100
# 7          WanderJaunt                            100
# 8                 Wyre                            100
# 9              Lantern                            100
# 10   Lora DiCarlo Inc.                            100
# 11            Bitfront                            100
# 12              Assure                            100
# 13             GloriFi                            100
# 14                Kite                            100
# 15              Wavely                            100
# 16        Fifth Season                            100
# 17             Argo AI                            100
# 18          CommonBond                            100
# 19            The Wing                            100
# 20              Edmodo                            100
# 21                Haus                            100
# 22             BlockFi                            100
# 23               Pesto                            100
# 24          Kitty Hawk                            100
# 25            Subspace                            100
# 26      Halcyon Health                            100
# 27               Ahead                            100

# %% [markdown]
# Média de demissões:

# %%
pd.read_sql('''SELECT ROUND(AVG(impacted_workforce_percentage), 2)
               AS mean_impacted_workforce_percentage
               FROM data''', conn)
# Out:
#    mean_impacted_workforce_percentage
# 0                               23.88

# %% [markdown]
# #### Representações gráficas

# %% [markdown]
# Representando a distribuição dos valores (sem NULL) através de um histograma e de um boxplot:

# %%
plot_data = pd.read_sql('''SELECT impacted_workforce_percentage FROM data
                           WHERE impacted_workforce_percentage IS NOT NULL''', conn)
fig, axs = plt.subplots(1, 2, figsize = (12,6))
axs[0].boxplot(plot_data)
axs[0].set_title('Boxplot da distribuição da porcentagem de demissões', fontsize = '11')
axs[0].set_ylabel('Porcentagem da força de trabalho demitida')


axs[1].hist(plot_data, color = 'darkblue')
axs[1].set_title('Histograma da distribuição de demissões', fontsize = '11')
axs[1].set_xlabel('Porcentagem da força de trabalho demitida')
axs[1].set_ylabel('Número de empresas')
# Out:
# Text(0, 0.5, 'Número de empresas')

# %% [markdown]
# ### reported_date

# %% [markdown]
# #### Representações analíticas

# %% [markdown]
# Anos em que ocorreram demissões:

# %%
pd.read_sql('''SELECT DISTINCT STRFTIME('%Y', reported_date) AS Layoff_Years
               FROM data
               WHERE STRFTIME('%Y', reported_date) <> 'None' 
               ORDER BY STRFTIME('%Y', reported_date)''', conn)
# Out:
#   Layoff_Years
# 0         2022
# 1         2023

# %% [markdown]
# Meses em que ocorreram demissões:

# %%
pd.read_sql('''SELECT DISTINCT STRFTIME('%m', reported_date) AS Layoff_Months
               FROM data
               WHERE STRFTIME('%m', reported_date) <> 'None' 
               ORDER BY STRFTIME('%m', reported_date)''', conn)
# Out:
#    Layoff_Months
# 0             01
# 1             02
# 2             03
# 3             04
# 4             05
# 5             06
# 6             07
# 7             08
# 8             09
# 9             10
# 10            11
# 11            12

# %% [markdown]
# Dias em que ocorreram demissões:

# %%
pd.read_sql('''SELECT DISTINCT STRFTIME('%d', reported_date) AS Layoff_Days
               FROM data
               WHERE STRFTIME('%d', reported_date) <> 'None' 
               ORDER BY STRFTIME('%d', reported_date)''', conn)
# Out:
#    Layoff_Days
# 0           01
# 1           02
# 2           03
# 3           04
# 4           05
# 5           06
# 6           07
# 7           08
# 8           09
# 9           10
# 10          11
# 11          12
# 12          13
# 13          14
# 14          15
# 15          16
# 16          17
# 17          18
# 18          19
# 19          20
# 20          21
# 21          22
# 22          23
# 23          24
# 24          25
# 25          26
# 26          27
# 27          28
# 28          29
# 29          30
# 30          31

# %% [markdown]
# ### industry

# %% [markdown]
# #### Representações analíticas

# %% [markdown]
# Diferentes indústrias que demitiram:

# %%
pd.read_sql('''SELECT DISTINCT industry FROM data''', conn)
# Out:
#                                               industry
# 0                                    Fintech, payments
# 1                                Advertising platforms
# 2                                      Saas, analytics
# 3                              fintech, data analytics
# 4                                          Health Care
# ..                                                 ...
# 284  Enterprise software, Management information sy...
# 285                cybersecurity, cloud infrastructure
# 286                                Autonomous vehicles
# 287                        Insurtech, machine learning
# 288                         enterprise tech, analytics
#
# [289 rows x 1 columns]

# %% [markdown]
# Top 10 indústrias que demitiram mais de uma vez:

# %%
top10_layoffs = pd.read_sql('''SELECT industry, COUNT(*) AS industry_count
               FROM data
               GROUP BY industry
               HAVING industry_count > 1
               ORDER BY industry_count DESC
               LIMIT 10''', conn)
top10_layoffs
# Out:
#          industry  industry_count
# 0         Fintech              24
# 1     Health Care              17
# 2        PropTech              15
# 3      E-commerce              13
# 4   Cybersecurity              10
# 5        Proptech               9
# 6       InsurTech               7
# 7         FinTech               7
# 8  Cryptocurrency               7
# 9  Transportation               6

# %% [markdown]
# #### Representação gráfica

# %%
plot_data = top10_layoffs
colors = ['darkblue']*2 + ['grey']*8

plt.figure(figsize = (16,5))
plt.suptitle('Top 10 indústrias que mais demitiram entre 2022 e 2023', fontsize = '16')
plt.title('Fintechs e a indústria de Health Care lideram o ranking, contando com 24 e 17 empresas que demitiram, respectivamente.')
plt.bar(plot_data['industry'], plot_data['industry_count'], color = colors)
plt.xlabel('Indústria ao qual pertence a empresa')
plt.ylabel('Número de empresas que realizaram demissões')
# Out:
# Text(0, 0.5, 'Número de empresas que realizaram demissões')

# %% [markdown]
# ### headquarter_location

# %% [markdown]
# #### Representações analíticas

# %% [markdown]
# Diferentes localizações das empresas que demitiram:

# %%
pd.read_sql('''SELECT DISTINCT headquarter_location FROM data
               ORDER BY headquarter_location''', conn)
# Out:
#     headquarter_location
# 0            Alameda, CA
# 1         Alpharetta, GA
# 2                Atlanta
# 3                 Austin
# 4             Austin, TX
# ..                   ...
# 129          Walpole, MA
# 130       Washington, DC
# 131        Waterford, MI
# 132        Williston, VT
# 133       Wilmington, NC
#
# [134 rows x 1 columns]

# %% [markdown]
# Top 10 locais com base no número de empresas que demitiram:

# %%
top10_locations = pd.read_sql('''SELECT headquarter_location, COUNT(*) as location_count
               FROM data
               GROUP BY headquarter_location
               ORDER BY location_count DESC
               LIMIT 10''', conn)

top10_locations
# Out:
#   headquarter_location  location_count
# 0        San Francisco             136
# 1             New York              77
# 2              Seattle              21
# 3          Los Angeles              20
# 4               Boston              16
# 5              Chicago              12
# 6           Austin, TX               6
# 7            San Diego               5
# 8        Palo Alto, CA               5
# 9    Mountain View, CA               5

# %%
plot_data = top10_locations
colors = ['darkblue']*2 + ['grey']*8

plt.figure(figsize = (16,5))
plt.suptitle('Top 10 locais com mais empresas sediadas que demitiram entre 2022 e 2023', fontsize = '16')
plt.title('San Francisco e Nova York lideram o ranking, contando com 126 e 77 empresas que demitiram, respectivamente.')
plt.bar(plot_data['headquarter_location'], plot_data['location_count'], color = colors)
plt.xlabel('Local da sede')
plt.ylabel('Número de empresas que demitiram')
# Out:
# Text(0, 0.5, 'Número de empresas que demitiram')

# %% [markdown]
# ### sources

# %% [markdown]
# #### Representações analíticas

# %% [markdown]
# Diferentes fontes dos dados:

# %%
pd.read_sql('''SELECT DISTINCT sources FROM data
               ORDER BY sources''', conn)
# Out:
#          sources
# 0          360dx
# 1      AMBCrypto
# 2          AdAge
# 3       Airtable
# 4    Alex Beller
# ..           ...
# 216       WeWork
# 217        Wired
# 218   Wistia CEO
# 219       dot.LA
# 220   impact.com
#
# [221 rows x 1 columns]

# %% [markdown]
# Principais 5 sites dos quais foram retirados dados:

# %%
pd.read_sql('''SELECT sources, COUNT(*) AS sources_count FROM data
               GROUP BY sources
               ORDER BY sources_count DESC
               LIMIT 5''', conn)
# Out:
#             sources  sources_count
# 0        TechCrunch             52
# 1   The Information             23
# 2  Business Insider             23
# 3      Calcalistech             20
# 4          LinkedIn             16

# %% [markdown]
# ### status

# %% [markdown]
# #### Representações analíticas

# %% [markdown]
# Número de empresas privadas e públicas que demitiram:

# %%
status_count = pd.read_sql('''SELECT (SELECT COUNT(*) FROM data
                          WHERE status = 'Private') AS Private_Companies_Count,
                      (SELECT COUNT(*) FROM data
                       WHERE status = 'Public') AS Public_Companies_Count''', conn)

status_count
# Out:
#    Private_Companies_Count  Public_Companies_Count
# 0                      370                     119

# %% [markdown]
# #### Representações gráficas

# %%
plot_data = status_count
x = ['Número de empresas públicas', 'Número de empresas privadas']
y = sorted(status_count.values[0])
y = dict(zip(['public', 'private'], y))
private = y['private']
public = y['public']
plt.bar(x, y.values(), color = ['gray', 'darkblue'])
plt.yticks([])
plt.text(0 - 0.05,  public + 3, s = f'{public}')
plt.text(1 - 0.05,  private + 3, s = f'{private}')
plt.suptitle('Contagem de empresas que demitiram por condição')
plt.title(f'Empresas privadas dominam o cenário com {round(private/public, 1)} vezes mais empresas que realizaram demissões.')
# Out:
# Text(0.5, 1.0, 'Empresas privadas dominam o cenário com 3.1 vezes mais empresas que realizaram demissões.')

# %% [markdown]
# ### additional_notes

# %% [markdown]
# #### Representações analíticas

# %% [markdown]
# Obtendo as empresas que possuem notas adicionais:

# %%
pd.read_sql('''SELECT company, additional_notes FROM data
               WHERE additional_notes <> '' ''', conn)
# Out:
#             company                                   additional_notes
# 0    Thirty Madison  Per Axios, 22 of the employees laid off were f...
# 1         SundaySky  Layoffs affect employees in the U.S., Israel, ...
# 2       Sourcepoint  Company did not respond to a request to confir...
# 3              Nate  Nate reportedly had two layoffs. In June, the ...
# 4         Outschool  Outschool laid off 31 people, or 18% of the co...
# 5              Rasa  Rasa was founded in Berlin but moved its headq...
# 6       100 Thieves  More than a dozen employees were reportedly la...
# 7             Orbit  Orbit CEO Patrick Woods announced at least 14 ...
# 8        Cybereason  Affected employees are in U.S., Israel, and Eu...
# 9   Rad Power Bikes  First round of layoffs was in April, second ro...
# 10           Gopuff  First round of layoffs was in January, second ...
# 11         OnlyFans  OnlyFans is based in the UK but has a sizeable...
# 12         Talkdesk  Sources say hundreds of employees have been la...
# 13          StubHub  StubHub announced they would be letting go of ...
# 14         Cerebral  The company previously laid off employees in May.
# 15            Elemy   The company previously laid off workers in July.
# 16           TikTok  TikTok is owned by China-based ByteDance, but ...
# 17  Varonis Systems  Half of its layoffs happened at its R&D center...
# 18         Playtika  Closing studios in London, Montreal, and Los A...
# 19          Peloton      Peloton previously laid off 3,584 in February
# 20             Doma    The company previously laid off workers in May.
# 21           Oracle  The Information reported thousands of people w...

# %% [markdown]
# ---

# %% [markdown]
# # Conclusões

# %% [markdown]
# Com isso, terminamos uma análise univariada acerca do dataset de tech layoffs disponível no Kaggle. Essa é uma forma prática de treinar, ao mesmo tempo, visualização de dados por meio da biblioteca matplotlib e consultas através da linguagem SQL via banco de dados SQlite.
